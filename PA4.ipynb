# %% [markdown]
# # Programming Assessment 4

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## PART A: VISCOMM DATAFRAME

# %%
df = pd.read_excel("board2.xlsx")
df["Average"] = df[["Math", "GEAS", "Electronics", "Communication"]].mean(
    axis=1)

# %%
vis_comm_filter = (df["Hometown"] == "Visayas") & (
    df["Track"] == "Communication")

# %%
VisComm = df[vis_comm_filter][
    ["Name", "Gender", "Math", "Electronics", "Average"]
]

# %%
print("=== PART A: VisComm ===")
display(VisComm)
print("Row count:", len(VisComm))
# Out:
# === PART A: VisComm ===
#    Name  Gender  Math  Electronics  Average
# 10  S11  Female    48           56    54.75
# 11  S12    Male    89           67    76.00
# 17  S18    Male    81           40    63.50
# 21  S22  Female    64           39    62.50
# 27  S28    Male    85           53    67.75
# Row count: 5

# %% [markdown]
# ## PART B: VISFEMALE DATAFRAME

# %%
vis_female_filter = (df["Hometown"] == "Visayas") & (df["Gender"] == "Female")
VisFemale = df[vis_female_filter][
    ["Name", "Track", "GEAS", "Electronics", "Average"]
]

# %%
print("\n=== PART B: VisFemale ===")
display(VisFemale)
# Out:
# === PART B: VisFemale ===
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics    86           45    75.50
# 10  S11     Communication    48           56    54.75
# 20  S21  Microelectronics    68           51    68.50
# 21  S22     Communication    89           39    62.50
# 23  S24  Microelectronics    60           45    57.75
# 25  S26   Instrumentation    83           47    65.75

# %% [markdown]
# ## PART C: CATEGORY MEANS & PLOTTING

# %%
mean_track = df.groupby("Track")["Average"].mean()
mean_gender = df.groupby("Gender")["Average"].mean()
mean_hometown = df.groupby("Hometown")["Average"].mean()

# %%
print("\n=== SUMMARY TABLES ===")
print("\nMean by Track:\n", mean_track)
print("\nMean by Gender:\n", mean_gender)
print("\nMean by Hometown:\n", mean_hometown)
# Out:
# === SUMMARY TABLES ===
#
# Mean by Track:
#  Track
# Communication       67.975
# Instrumentation     65.225
# Microelectronics    67.500
# Name: Average, dtype: float64
#
# Mean by Gender:
#  Gender
# Female    66.616667
# Male      67.183333
# Name: Average, dtype: float64
#
# Mean by Hometown:
#  Hometown
# Luzon       68.083333
# Mindanao    66.678571
# Visayas     65.750000
# Name: Average, dtype: float64

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=True)

mean_track.plot(
    kind="bar",
    ax=axes[0],
    title="Mean Average by Track",
    ylabel="Average Score",
    rot=0,
)

mean_gender.plot(
    kind="bar",
    ax=axes[1],
    title="Mean Average by Gender",
    ylabel="Average Score",
    rot=0,
)

mean_hometown.plot(
    kind="bar",
    ax=axes[2],
    title="Mean Average by Hometown",
    ylabel="Average Score",
    rot=0,
)
# Plot gender and hometown on axes[1] and axes[2] here...

plt.tight_layout()
plt.show()

# %%
plt.tight_layout()
plt.show()

# %%
print("\n=== HIGHEST CATEGORY MEANS ===")
print(f"Track: {mean_track.idxmax()} ({mean_track.max():.2f})")
print(f"Gender: {mean_gender.idxmax()} ({mean_gender.max():.2f})")
print(f"Hometown: {mean_hometown.idxmax()} ({mean_hometown.max():.2f})")
# Out:
# === HIGHEST CATEGORY MEANS ===
# Track: Communication (67.97)
# Gender: Male (67.18)
# Hometown: Luzon (68.08)
